# %%
{
 "cells": [
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from src.features import engineer_features, process_dataset\\nimport pandas as pd\\n\\n# Test single ticker\\ndf = pd.read_parquet('data/raw/AAPL.parquet')\\ndf_featured = engineer_features(df)\\nprint('Features created:', len(df_featured.columns))\\nprint('\\nSample:\\n', df_featured.tail())"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Process all\\nprocess_dataset()\\nprint('✅ All features engineered!')"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 }
}
